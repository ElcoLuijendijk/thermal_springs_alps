# %% [markdown]
# # Compare thermal springs Alps and North America
#
# Compare the heat flux & distribution of springs to a thermal spring database from North America by Ferguson and Grasby (2011) Geofluids.

# %%
import string
import itertools

import pandas as pd
import geopandas as gp
import numpy as np
import scipy.stats
import matplotlib.pyplot as pl

import shapely.ops as ops
import pyproj
from functools import partial
from cartopy import crs as ccrs

import rasterio as rio
from rasterstats import zonal_stats

import matplotlib
matplotlib.rcParams.update({'errorbar.capsize': 5})
pl.rcParams['mathtext.default'] = 'regular'

from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

import scipy.stats

import pyGISlib

from lib.mapping_functions import *
# Out:
# /home/elco/python_scripts/thermal_springs_alps/lib/mapping_functions.py:10: MatplotlibDeprecationWarning:
# The mpl_toolkits.axes_grid module was deprecated in Matplotlib 2.1 and will be removed two minor releases later. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist, which provide the same functionality instead.
#   from mpl_toolkits.axes_grid.inset_locator import inset_axes

# %% [markdown]
# ## Some parameters

# %%
areas = ['Alps', 'APPALACHIAN MTS.', 'CASCADE RANGE', 
         'COAST MOUNTAINS', 'COAST RANGES',
         'MACKENZIE MTS.', 'ROCKY MOUNTAINS', 'SIERRA NEVADA',]

area_labels = ['Alps', 'Appalachians', 'Cascades', 
               'Coastal Mts.', 'Coastal ranges', 
               'Mackenzie Mts.', 'Rocky Mts', 'Sierra Nevada']

area_labels_short = ['AL', 'AP',
                     'CA', 'CM', 'CR', 
                     'MK', 'RM', 'SN']

cols = ['n_springs']

dri = pd.DataFrame(index=areas, columns=cols)

dri['area_name'] = area_labels

dri['area_name_short'] = area_labels_short

dr = gp.GeoDataFrame(dri)

# %% [markdown]
# ## Read thermal spring database North America

# %%
fn = 'data/springs_database_North_America_Grant_Ferguson_mod.csv'
df = pd.read_csv(fn)
print(df.columns)
df.head()
# Out:
# Index(['Name', 'Discharge (L/s)', 'Temperature', 'Air Temperature', 'Delta T',
#        'Precip', 'Source', 'State', 'Log Discharge', 'Latitude', 'Longitude',
#        'Approx Heat Flow (W)', 'Corrected Heat Flow', 'Log approx heat flow',
#        'Crustal Heat Flow (mW/m2)', 'Heat Flow Area (m2)',
#        'Heat Flow Area (km2)', 'Precip Area (m2)', 'hfa/pa'],
#       dtype='object')
#                   Name  Discharge (L/s)  Temperature  Air Temperature  \
# 0           Twin Lakes         4.500000         21.0              5.4
# 1        Upper Klawasi         3.500000         17.0              0.0
# 2  Battleship Mountain         1.166667         19.0              0.0
# 3        Lower Klawasi         2.000000         20.0              0.0
# 4          Barnes Lake         0.500000         26.0              4.1
#
#    Delta T  Precip             Source   State      Log Discharge  Latitude  \
# 0     15.6  2187.0  Motyka et al 1983  Alaska   0.65321251377534     56.70
# 1     17.0   366.0  Motyka et al 1983  Alaska   0.54406804435028     62.08
# 2     19.0   413.0  Motyka et al 1983  Alaska   0.06694678963061     64.81
# 3     20.0   379.0  Motyka et al 1983  Alaska   0.30102999566398     62.06
# 4     21.9  1961.0  Motyka et al 1983  Alaska  -0.30102999566398     56.68
#
#    Longitude  Approx Heat Flow (W)  Corrected Heat Flow Log approx heat flow  \
# 0    -132.28              207108.0        293716.800000     5.31619687479279
# 1    -145.00              102508.0        248948.000000     5.01075776022375
# 2    -162.91               43932.0         92745.333333     4.64278097492916
# 3    -145.22               83680.0        167360.000000      4.9226216715232
# 4    -131.88               33472.0         45814.800000     4.52468166285116
#
#    Crustal Heat Flow (mW/m2)  Heat Flow Area (m2)  Heat Flow Area (km2)  \
# 0                       66.3         4.430118e+06              4.430118
# 1                       77.2         3.224715e+06              3.224715
# 2                       65.9         1.407365e+06              1.407365
# 3                       77.2         2.167876e+06              2.167876
# 4                       66.3         6.910226e+05              0.691023
#
#    Precip Area (m2)            hfa/pa
# 0  64888.8888888889  68.2723609991942
# 1  301573.770491803   10.692955891515
# 2  89084.7457627119  15.7980435587645
# 3  166416.886543536  13.0267768655873
# 4  8040.79551249363  85.9395843807608

# %% [markdown]
# ## Convert data to geopandas dataframe

# %%
from shapely.geometry import Point

gm = [Point(x, y) for x, y in zip(df.Longitude, df.Latitude)]

ds = gp.GeoDataFrame(df, geometry=gm)

# %% [markdown]
# ## Load shapefile with areas to select hot springs

# %%
## Load shapefile with orogen shapes
fns = 'GIS_data/ne_10m_geography_regions_polys.shp'

da = gp.read_file(fns)

# %% [markdown]
# ## Go through all areas:

# %%
def calc_area(geom):
    
    l1 = geom.geometry.bounds[1]
    l2 = geom.geometry.bounds[2]
    print(geom.bounds)
    
    new_proj =pyproj.Proj(proj='aeqd', lat_0=l1, lon_0=l2)
    
    geom_area = geom.to_crs(new_proj)
    
    return geom_area.geometry.area

# %%
crs = ccrs.PlateCarree()

fig, axs = pl.subplots(2, 4, figsize=(10, 5), subplot_kw={'projection': crs})

axs = axs.ravel()

plot_i = 0

for area_i, area in enumerate(areas):
    
    print(area)
    
    if area in da['name'].values:
        ind = da['name'] == area
        #print(da.loc[ind])
        dai = da.loc[ind]

        # select_springs in polygon
        in_polygon = [dai.contains(dsgi).values[0] for dsgi in ds.geometry.values]
        dsi = ds.loc[in_polygon]
        print(len(dsi))
        dr.loc[area, 'n_springs'] = len(dsi)
        
        #world = world.to_crs({'init': 'epsg:3395'})
        area_poly = dai.to_crs("+proj=eck4 +lon_0=0 +x_0=0 +y_0=0 +datum=WGS84 +units=m +no_defs").area.values[0]
        
        dr.loc[area, 'geometry'] = da.loc[ind, 'geometry'].values
        
        dr.loc[area, 'area'] = area_poly
        dr.loc[area, 'total_heat_flow_W'] = dsi['Approx Heat Flow (W)'].sum()
        dr.loc[area, 'spring_HF_density_mW_m-2'] = dsi['Approx Heat Flow (W)'].sum() / area_poly * 1000.0
        dr.loc[area, 'total_discharge_m3_s'] = dsi['Discharge (L/s)'].sum() / 1000.0
        dr.loc[area, 'avg_background_heat_flow_mWm-2'] = dsi['Crustal Heat Flow (mW/m2)'].mean()
        #dr.loc[area, 'percentage_of_total_recharge'] = dsi['Precip Area (m2)'].sum() / dr.loc[area, 'area'] * 100

        ##############
        # make figure
        ##############
        ax = axs[plot_i]

        #ax.stock_img()

        ax.set_title(area)

        #dai.plot(ax=ax, color='gray')
        ax.add_geometries(dai['geometry'], facecolor='None', edgecolor='gray', crs=crs)

        #dsi.plot(ax=ax, edgecolor='black', facecolor='None')
        ax.scatter(dsi['Longitude'], dsi['Latitude'], edgecolor='orange', transform=crs)

        buffer = 5.0

        ax.set_xlim(dai.bounds.minx.values[0]-buffer, dai.bounds.maxx.values[0]+buffer)
        ax.set_ylim(dai.bounds.miny.values[0]-buffer, dai.bounds.maxy.values[0]+buffer)
        
        plot_i += 1

axs[-1].remove()
fig.tight_layout()

fig.savefig('fig/distribution_springs_north_america.png', dpi=200)
#########

year = 365.25 * 24 * 3600
dr['percentage_of_total_heat_flow'] = \
    dr['total_heat_flow_W'] / (dr['avg_background_heat_flow_mWm-2'] / 1000.0 * dr['area']) * 100.0
dr['total_discharge_mm_a-1'] = dr['total_discharge_m3_s'] * year / dr['area'] * 1000.0
# Out:
# Alps
# APPALACHIAN MTS.
# 18
# /usr/local/lib/python3.6/dist-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# CASCADE RANGE
# 40
# /usr/local/lib/python3.6/dist-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# /usr/local/lib/python3.6/dist-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# COAST MOUNTAINS
# 21
# COAST RANGES
# 55
# /usr/local/lib/python3.6/dist-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# /usr/local/lib/python3.6/dist-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# MACKENZIE MTS.
# 10
# ROCKY MOUNTAINS
# 220
# /usr/local/lib/python3.6/dist-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# /usr/local/lib/python3.6/dist-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# SIERRA NEVADA
# 40
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:59: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.

# %%
dr.head()
# Out:
#                  n_springs       area_name area_name_short  \
# Alps                   NaN            Alps              AL
# APPALACHIAN MTS.        18    Appalachians              AP
# CASCADE RANGE           40        Cascades              CA
# COAST MOUNTAINS         21    Coastal Mts.              CM
# COAST RANGES            55  Coastal ranges              CR
#
#                                                            geometry  \
# Alps                                                           None
# APPALACHIAN MTS.  POLYGON ((-64.97519 48.16923, -65.15880 48.062...
# CASCADE RANGE     POLYGON ((-119.01110 50.86066, -119.10973 50.6...
# COAST MOUNTAINS   POLYGON ((-134.21074 59.93110, -134.00292 59.6...
# COAST RANGES      POLYGON ((-124.31286 48.26301, -123.78905 48.1...
#
#                           area  total_heat_flow_W  spring_HF_density_mW_m-2  \
# Alps                       NaN                NaN                       NaN
# APPALACHIAN MTS.  8.525581e+11       3.250012e+07                  0.038121
# CASCADE RANGE     1.428857e+11       5.388678e+07                  0.377132
# COAST MOUNTAINS   2.149131e+11       2.928910e+07                  0.136283
# COAST RANGES      1.653158e+11       8.359235e+06                  0.050565
#
#                   total_discharge_m3_s  avg_background_heat_flow_mWm-2  \
# Alps                               NaN                             NaN
# APPALACHIAN MTS.              0.506012                       57.583333
# CASCADE RANGE                 0.296381                       54.955000
# COAST MOUNTAINS               0.156313                       63.409524
# COAST RANGES                  0.067350                       80.318182
#
#                   percentage_of_total_heat_flow  total_discharge_mm_a-1
# Alps                                        NaN                     NaN
# APPALACHIAN MTS.                       0.066201                0.018730
# CASCADE RANGE                          0.686256                0.065459
# COAST MOUNTAINS                        0.214926                0.022953
# COAST RANGES                           0.062956                0.012857

# %% [markdown]
# ## Add info on the Alps
#
# This uses summary data generated using the analyze_spring_heat_flux_new.ipynb notebook

# %%
fnb = 'GIS_data/outline_alps_final.shp'
db = gp.read_file(fnb)
dr.loc['Alps', 'geometry'] = db['geometry'][0]

# %%
fna = 'data/summary_thermal_springs_data.csv'
dfa = pd.read_csv(fna)
dfa = dfa.set_index('dataset')

# %% [markdown]
# ### Add heat flow data Alps

# %%
minmaxs1 = ['_min', '', '_max']
minmaxs2 = ['min', 'best', 'max']

for mm1, mm2 in zip(minmaxs1, minmaxs2):
    #dr.loc['Alps', 'percentage_of_total_heat_flow%s' % mm1] = dfa.loc['Alps', 'spring_heat_flux_est_percentage_%s' % mm1]
    dr.loc['Alps', 'spring_HF_density%s_mW_m-2' % mm1] = dfa.loc['Alps', 'total_H_net_%s_mW_m-2' % mm2]

dr.loc['Alps', 'area'] = dfa.loc['Alps', 'area_km2'] * 1e6
dr.loc['Alps', 'n_springs'] = dfa.loc['Alps', 'n_springs']

dr.loc['Alps', 'avg_background_heat_flow_mWm-2'] = 76
    
dr['spring_HF_density_mW_m-2'], dr['area']
# Out:
# (Alps                0.550000
#  APPALACHIAN MTS.    0.038121
#  CASCADE RANGE       0.377132
#  COAST MOUNTAINS     0.136283
#  COAST RANGES        0.050565
#  MACKENZIE MTS.      0.143606
#  ROCKY MOUNTAINS     0.507204
#  SIERRA NEVADA       1.497902
#  Name: spring_HF_density_mW_m-2, dtype: float64,
#  Alps                2.023559e+11
#  APPALACHIAN MTS.    8.525581e+11
#  CASCADE RANGE       1.428857e+11
#  COAST MOUNTAINS     2.149131e+11
#  COAST RANGES        1.653158e+11
#  MACKENZIE MTS.      3.103657e+11
#  ROCKY MOUNTAINS     1.080046e+12
#  SIERRA NEVADA       7.026051e+10
#  Name: area, dtype: float64)

# %% [markdown]
# ### Add fluid flow data

# %%
dr.loc['Alps', 'total_discharge_mm_a-1'] = \
    dfa.loc['Alps', 'total_spring_flux_km3_yr-1'] * 1e9 / (dfa.loc['Alps', 'area_km2'] * 1e6) * 1e3
dfa.columns.tolist()

dr['total_discharge_mm_a-1']
# Out:
# Alps                0.296507
# APPALACHIAN MTS.    0.018730
# CASCADE RANGE       0.065459
# COAST MOUNTAINS     0.022953
# COAST RANGES        0.012857
# MACKENZIE MTS.      0.024759
# ROCKY MOUNTAINS     0.108303
# SIERRA NEVADA       0.174816
# Name: total_discharge_mm_a-1, dtype: float64

# %%
dr['spring_density'] = (dr['area'] / 1e6) / dr['n_springs']

# %%
dr
# Out:
#                  n_springs       area_name area_name_short  \
# Alps                   311            Alps              AL
# APPALACHIAN MTS.        18    Appalachians              AP
# CASCADE RANGE           40        Cascades              CA
# COAST MOUNTAINS         21    Coastal Mts.              CM
# COAST RANGES            55  Coastal ranges              CR
# MACKENZIE MTS.          10  Mackenzie Mts.              MK
# ROCKY MOUNTAINS        220       Rocky Mts              RM
# SIERRA NEVADA           40   Sierra Nevada              SN
#
#                                                            geometry  \
# Alps              POLYGON ((5.702513796361931 45.47713659882108,...
# APPALACHIAN MTS.  POLYGON ((-64.97518737201227 48.16923497422596...
# CASCADE RANGE     POLYGON ((-119.0110977855413 50.86066315311908...
# COAST MOUNTAINS   POLYGON ((-134.210743781635 59.93109772343163,...
# COAST RANGES      POLYGON ((-124.3128555980413 48.26300690311905...
# MACKENZIE MTS.    POLYGON ((-131.1191300121038 65.78961823124413...
# ROCKY MOUNTAINS   POLYGON ((-124.565235969135 59.71057770390036,...
# SIERRA NEVADA     POLYGON ((-118.1984146800725 35.1114566101503,...
#
#                           area  total_heat_flow_W  spring_HF_density_mW_m-2  \
# Alps              2.023559e+11                NaN                  0.550000
# APPALACHIAN MTS.  8.525581e+11       3.250012e+07                  0.038121
# CASCADE RANGE     1.428857e+11       5.388678e+07                  0.377132
# COAST MOUNTAINS   2.149131e+11       2.928910e+07                  0.136283
# COAST RANGES      1.653158e+11       8.359235e+06                  0.050565
# MACKENZIE MTS.    3.103657e+11       4.457039e+07                  0.143606
# ROCKY MOUNTAINS   1.080046e+12       5.478040e+08                  0.507204
# SIERRA NEVADA     7.026051e+10       1.052434e+08                  1.497902
#
#                   total_discharge_m3_s  avg_background_heat_flow_mWm-2  \
# Alps                               NaN                       76.000000
# APPALACHIAN MTS.              0.506012                       57.583333
# CASCADE RANGE                 0.296381                       54.955000
# COAST MOUNTAINS               0.156313                       63.409524
# COAST RANGES                  0.067350                       80.318182
# MACKENZIE MTS.                0.243504                       77.430000
# ROCKY MOUNTAINS               3.706632                      114.535455
# SIERRA NEVADA                 0.389213                       73.915000
#
#                   percentage_of_total_heat_flow  total_discharge_mm_a-1  \
# Alps                                        NaN                0.296507
# APPALACHIAN MTS.                       0.066201                0.018730
# CASCADE RANGE                          0.686256                0.065459
# COAST MOUNTAINS                        0.214926                0.022953
# COAST RANGES                           0.062956                0.012857
# MACKENZIE MTS.                         0.185466                0.024759
# ROCKY MOUNTAINS                        0.442836                0.108303
# SIERRA NEVADA                          2.026520                0.174816
#
#                   spring_HF_density_min_mW_m-2  spring_HF_density_max_mW_m-2  \
# Alps                                      0.42                          0.72
# APPALACHIAN MTS.                           NaN                           NaN
# CASCADE RANGE                              NaN                           NaN
# COAST MOUNTAINS                            NaN                           NaN
# COAST RANGES                               NaN                           NaN
# MACKENZIE MTS.                             NaN                           NaN
# ROCKY MOUNTAINS                            NaN                           NaN
# SIERRA NEVADA                              NaN                           NaN
#
#                  spring_density
# Alps                    650.662
# APPALACHIAN MTS.        47364.3
# CASCADE RANGE           3572.14
# COAST MOUNTAINS           10234
# COAST RANGES            3005.74
# MACKENZIE MTS.          31036.6
# ROCKY MOUNTAINS          4909.3
# SIERRA NEVADA           1756.51

# %% [markdown]
# ## Show results in a figure

# %% [markdown]
# ## Some figure parameters:

# %%
ms=10
ybuffer = 0.025

# variables on y-axis:
yvar = 'spring_HF_density_mW_m-2'
ylabel = r'Net HF springs (mW m$^{-2}$)'
yvar2 = 'total_discharge_mm_a-1'
ylabel2 = r'Spring discharge ($mm\;a^{-1}$)'

# y-axis extent
ylim1 = [0, 2.0]
ylim2 = [0, 0.6]

# map projection
crs = ccrs.PlateCarree()

# marker size
s = 100

# %%
dr = dr.sort_values(by=yvar2, ascending=False)
dr
# Out:
#                  n_springs       area_name area_name_short  \
# Alps                   311            Alps              AL
# SIERRA NEVADA           40   Sierra Nevada              SN
# ROCKY MOUNTAINS        220       Rocky Mts              RM
# CASCADE RANGE           40        Cascades              CA
# MACKENZIE MTS.          10  Mackenzie Mts.              MK
# COAST MOUNTAINS         21    Coastal Mts.              CM
# APPALACHIAN MTS.        18    Appalachians              AP
# COAST RANGES            55  Coastal ranges              CR
#
#                                                            geometry  \
# Alps              POLYGON ((5.70251 45.47714, 5.84122 45.60113, ...
# SIERRA NEVADA     POLYGON ((-118.19841 35.11146, -118.59527 34.8...
# ROCKY MOUNTAINS   POLYGON ((-124.56524 59.71058, -123.32653 59.0...
# CASCADE RANGE     POLYGON ((-119.01110 50.86066, -119.10973 50.6...
# MACKENZIE MTS.    POLYGON ((-131.11913 65.78962, -129.73424 65.6...
# COAST MOUNTAINS   POLYGON ((-134.21074 59.93110, -134.00292 59.6...
# APPALACHIAN MTS.  POLYGON ((-64.97519 48.16923, -65.15880 48.062...
# COAST RANGES      POLYGON ((-124.31286 48.26301, -123.78905 48.1...
#
#                           area  total_heat_flow_W  spring_HF_density_mW_m-2  \
# Alps              2.023559e+11                NaN                  0.550000
# SIERRA NEVADA     7.026051e+10       1.052434e+08                  1.497902
# ROCKY MOUNTAINS   1.080046e+12       5.478040e+08                  0.507204
# CASCADE RANGE     1.428857e+11       5.388678e+07                  0.377132
# MACKENZIE MTS.    3.103657e+11       4.457039e+07                  0.143606
# COAST MOUNTAINS   2.149131e+11       2.928910e+07                  0.136283
# APPALACHIAN MTS.  8.525581e+11       3.250012e+07                  0.038121
# COAST RANGES      1.653158e+11       8.359235e+06                  0.050565
#
#                   total_discharge_m3_s  avg_background_heat_flow_mWm-2  \
# Alps                               NaN                       76.000000
# SIERRA NEVADA                 0.389213                       73.915000
# ROCKY MOUNTAINS               3.706632                      114.535455
# CASCADE RANGE                 0.296381                       54.955000
# MACKENZIE MTS.                0.243504                       77.430000
# COAST MOUNTAINS               0.156313                       63.409524
# APPALACHIAN MTS.              0.506012                       57.583333
# COAST RANGES                  0.067350                       80.318182
#
#                   percentage_of_total_heat_flow  total_discharge_mm_a-1  \
# Alps                                        NaN                0.296507
# SIERRA NEVADA                          2.026520                0.174816
# ROCKY MOUNTAINS                        0.442836                0.108303
# CASCADE RANGE                          0.686256                0.065459
# MACKENZIE MTS.                         0.185466                0.024759
# COAST MOUNTAINS                        0.214926                0.022953
# APPALACHIAN MTS.                       0.066201                0.018730
# COAST RANGES                           0.062956                0.012857
#
#                   spring_HF_density_min_mW_m-2  spring_HF_density_max_mW_m-2  \
# Alps                                      0.42                          0.72
# SIERRA NEVADA                              NaN                           NaN
# ROCKY MOUNTAINS                            NaN                           NaN
# CASCADE RANGE                              NaN                           NaN
# MACKENZIE MTS.                             NaN                           NaN
# COAST MOUNTAINS                            NaN                           NaN
# APPALACHIAN MTS.                           NaN                           NaN
# COAST RANGES                               NaN                           NaN
#
#                  spring_density
# Alps                    650.662
# SIERRA NEVADA           1756.51
# ROCKY MOUNTAINS          4909.3
# CASCADE RANGE           3572.14
# MACKENZIE MTS.          31036.6
# COAST MOUNTAINS           10234
# APPALACHIAN MTS.        47364.3
# COAST RANGES            3005.74

# %% [markdown]
# ## Construct figure:

# %%
x = ds['Longitude'].values
y = ds['Latitude'].values
z = pd.to_numeric(ds['Log approx heat flow'], errors='coerce').values

vlim = [2.0, 8.0]

panel_label = ['a', 'b']

zlabel = 'Log spring heat flow (W)'

zlabel_short = 'heat flow'

#fns = ['fig/map_spring_temperatures_Alps.png',
#       'fig/map_spring_discharge_Alps.png',
#       'fig/map_spring_heat_flow_Alps.png']

# add histograms
add_histo = True

# show heat flow data instead of the default temperature data
#show_HF_data = True

#from mpl_toolkits.basemap import maskoceans
#dem2 = maskoceans(x_raster, y_raster, dem)

xmin, xmax, ymin, ymax = (4.0, 18.0, 42.75, 49.0)

cmap = matplotlib.cm.get_cmap('coolwarm')

proj = ccrs.PlateCarree()

class_int = 0.25

fs_legend = 'small'
label_fs = 'medium'

legend_label = 'Springs with data'
legend_label_nd = 'no data'

hist_ylabel = 'N springs'

extent = [-170, -60, 30, 70]

long_ticks = [-150, -125, -100, -75]
lat_ticks = [30, 40, 50, 60, 70]
#extent = xmin, xmax, ymin, ymax

shps, shp_colors, shp_lss, shp_lws = None, None, None, None

# %%
# load dem

fnr = "/home/elco/GIS/global/elevation/etopo/ETOPO1_Bed_g_geotiff.tif"

print('loading dem')
dem, dimensions, origin, cellsize, nodata, projection = pyGISlib.read_raster_file(fnr)
ny, nx = dem.shape
xcoords = np.arange(origin[0], origin[0] + nx * cellsize[0], cellsize[0])
ycoords = np.arange(origin[1], origin[1] + ny * cellsize[1], cellsize[1])
x_raster, y_raster = np.meshgrid(xcoords, ycoords)

res = 5
x_raster = x_raster[::res, ::res]
y_raster = y_raster[::res, ::res]
dem = dem[::res, ::res]
# Out:
# loading dem

# %%
print(dem.shape)
# Out:
# (2161, 4321)

# %%
fig1, ax = make_map_figure(crs, extent, panel_label,
                      x_raster, y_raster, dem, 
                      x, y, z, vlim, class_int,
                      zlabel, hist_ylabel, legend_label, legend_label_nd, 
                      shps, shp_colors, shp_lss, shp_lws, mark_highest_value=False, 
                      add_histo=add_histo, histo_loc='lower left', add_inset_background=False,
                      long_ticks=long_ticks, lat_ticks=lat_ticks, return_ax=True, s=10)

#ax = pl.gca()

# add orogen locations:
for area_i, area, short_label in zip(itertools.count(), areas, area_labels_short):
    
    print(area, short_label)
    
    ind = da['name'] == area
    #print(da.loc[ind])
    dai = da.loc[ind]
    
    if area in da['name'].values:
        
        #dai.plot(ax=ax, color='gray')
        ax.add_geometries(dai['geometry'], facecolor='none', edgecolor='blue', crs=crs, zorder=200)
        
        d = dai['geometry'].centroid.values[0]
        c = d.coords[:][0]
        ax.text(c[0], c[1], short_label, fontsize='large', color='blue',
                    va='center', ha='center', transform=crs, weight='bold', zorder=202)

print('saving figure')
fig1.savefig('fig/map_spring_HF_NA.pdf')
print('done')
# Out:
# calculating hillshade
# creating color image
# /home/elco/python_scripts/thermal_springs_alps/lib/mapping_functions.py:257: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# /home/elco/python_scripts/thermal_springs_alps/lib/mapping_functions.py:257: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()
# Alps AL
# APPALACHIAN MTS. AP
# CASCADE RANGE CA
# COAST MOUNTAINS CM
# COAST RANGES CR
# MACKENZIE MTS. MK
# ROCKY MOUNTAINS RM
# SIERRA NEVADA SN
# saving figure
# done

# %%
dr.columns.tolist()
# Out:
# ['n_springs',
#  'area_name',
#  'area_name_short',
#  'geometry',
#  'area',
#  'total_heat_flow_W',
#  'spring_HF_density_mW_m-2',
#  'total_discharge_m3_s',
#  'avg_background_heat_flow_mWm-2',
#  'percentage_of_total_heat_flow',
#  'total_discharge_mm_a-1',
#  'spring_HF_density_min_mW_m-2',
#  'spring_HF_density_max_mW_m-2',
#  'spring_density']

# %%
yvars = ['spring_density', 'total_discharge_mm_a-1', 'spring_HF_density_mW_m-2']
ylabels = [r'Spring density ($km^2\;$spring$^{-1}$)', r'Spring discharge ($mm\;a^{-1}$)', 
           r'Net HF springs (mW m$^{-2}$)']

fig, axsi = pl.subplots(2, 3, figsize=(10, 7))
axs = axsi[1]

for ax, yvar, l in zip(axs, yvars, ylabels):
    ax.scatter(dr['area_name_short'], dr[yvar], 
                facecolor='gray',edgecolor='black', s=50)
    
    ax.set_ylabel(l)
    ax.set_xlabel('Orogen')

axs[0].set_yscale('log')

for i, axi in enumerate(axs):
    axi.spines['top'].set_visible(False)
    axi.spines['right'].set_visible(False)
    axi.text(0.03, 1.06, string.ascii_lowercase[i + 2], 
        weight='bold', transform=axi.transAxes, ha='left', va='bottom')

fig.tight_layout()

for ax in axsi[0]:
    ax.set_visible(False)
    
fig.savefig('fig/comparison_alps_NA_simple.pdf')

# %% [markdown]
# ## Zonal stats for relief, recharge

# %%
#gdal_translate -projwin -140 65 -60 30 mn30_grd1.tif mn30_grd1_clipped_NA.tif

#rasters_zs = ['/home/elco/GIS/global/recharge/degraaf2015/rch_mod.tif', 
#        '/home/elco/GIS/global/elevation/GMTED2010/mn30_grd1.tif']

rasters_zs = ['GIS_data/rch_mod.tif', 
              'GIS_data/mn30_grd1_clipped_NA.tif', 
              'GIS_data/heat_flow_NA_nat_neighbour.tif']

var_names_zs = ['avg_rch', 'elev', 'bg_hf']

stats = ['min', 'max', 'mean', 'std']

for raster, var_name in zip(rasters_zs, var_names_zs):
    
    print(raster, var_name)                               
                                   
    raster = rio.open(raster)
    zr = raster.read(1)
    #affine = raster.transform
    try:
        affine = raster.affine
    except:
        affine = raster.transform
        
    zs_cols = [var_name + '_' + stat for stat in stats]
    
    for zc in zs_cols:
        dr[zc] = np.nan
    
    for ix in dr.index:
        print(ix, zs_cols)
        #print(dr.loc[ix, 'geometry'])
        zs = zonal_stats(dr.loc[ix, 'geometry'], zr, affine=affine, stats=stats)
        print(zs)
        dr.loc[ix, zs_cols] = list(zs[0].values())
    
    #print(bla)
dr.loc['Alps', 'elev_std'] = 750.0
dr.loc['Alps', 'bg_hf_mean'] = 76.0
# Out:
# GIS_data/rch_mod.tif avg_rch
# Alps ['avg_rch_min', 'avg_rch_max', 'avg_rch_mean', 'avg_rch_std']
# [{'min': 0.0, 'max': 1.1004711238791696, 'mean': 0.5061954715167817, 'std': 0.18647329740393212}]
# SIERRA NEVADA ['avg_rch_min', 'avg_rch_max', 'avg_rch_mean', 'avg_rch_std']
# [{'min': 8.821898448477441e-05, 'max': 0.4526387055960452, 'mean': 0.14519322922531663, 'std': 0.1016126322128698}]
# ROCKY MOUNTAINS ['avg_rch_min', 'avg_rch_max', 'avg_rch_mean', 'avg_rch_std']
# [{'min': 3.1234953576548905e-07, 'max': 0.582716672656212, 'mean': 0.05807543541996578, 'std': 0.08656484587196915}]
# CASCADE RANGE ['avg_rch_min', 'avg_rch_max', 'avg_rch_mean', 'avg_rch_std']
# [{'min': 0.0, 'max': 1.5708055471296185, 'mean': 0.3908465345205654, 'std': 0.331347589700946}]
# MACKENZIE MTS. ['avg_rch_min', 'avg_rch_max', 'avg_rch_mean', 'avg_rch_std']
# [{'min': 1.2390351251475407e-05, 'max': 0.3349810871908877, 'mean': 0.06775560859016157, 'std': 0.06900616062799883}]
# COAST MOUNTAINS ['avg_rch_min', 'avg_rch_max', 'avg_rch_mean', 'avg_rch_std']
# [{'min': 0.0, 'max': 2.0777260318449433, 'mean': 0.656093986082574, 'std': 0.35263972615014066}]
# APPALACHIAN MTS. ['avg_rch_min', 'avg_rch_max', 'avg_rch_mean', 'avg_rch_std']
# [{'min': 0.0, 'max': 1.082997654163276, 'mean': 0.3618980648966855, 'std': 0.15072411369556982}]
# COAST RANGES ['avg_rch_min', 'avg_rch_max', 'avg_rch_mean', 'avg_rch_std']
# [{'min': 0.0, 'max': 1.962228259656588, 'mean': 0.3965485905948262, 'std': 0.3530032358477019}]
# GIS_data/mn30_grd1_clipped_NA.tif elev
# /home/elco/.local/lib/python3.6/site-packages/rasterstats/io.py:300: UserWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn("Setting nodata to -999; specify nodata explicitly")
# Alps ['elev_min', 'elev_max', 'elev_mean', 'elev_std']
# [{'min': None, 'max': None, 'mean': None, 'std': None}]
# SIERRA NEVADA ['elev_min', 'elev_max', 'elev_mean', 'elev_std']
# [{'min': 50.0, 'max': 4212.0, 'mean': 1606.575254460312, 'std': 873.8736318376556}]
# ROCKY MOUNTAINS ['elev_min', 'elev_max', 'elev_mean', 'elev_std']
# [{'min': 258.0, 'max': 4227.0, 'mean': 1844.2255962733295, 'std': 624.6283835037607}]
# CASCADE RANGE ['elev_min', 'elev_max', 'elev_mean', 'elev_std']
# [{'min': 0.0, 'max': 4279.0, 'mean': 1086.9873246374773, 'std': 519.883435578977}]
# MACKENZIE MTS. ['elev_min', 'elev_max', 'elev_mean', 'elev_std']
# [{'min': 60.0, 'max': 2711.0, 'mean': 1132.4409503562977, 'std': 433.496132419381}]
# COAST MOUNTAINS ['elev_min', 'elev_max', 'elev_mean', 'elev_std']
# [{'min': 0.0, 'max': 3637.0, 'mean': 1075.4315081150755, 'std': 584.10036635176}]
# APPALACHIAN MTS. ['elev_min', 'elev_max', 'elev_mean', 'elev_std']
# [{'min': -9.0, 'max': 1932.0, 'mean': 359.1082112350857, 'std': 209.36373677650496}]
# COAST RANGES ['elev_min', 'elev_max', 'elev_mean', 'elev_std']
# [{'min': -3.0, 'max': 2628.0, 'mean': 494.774684953692, 'std': 431.4542341481231}]
# GIS_data/heat_flow_NA_nat_neighbour.tif bg_hf
# Alps ['bg_hf_min', 'bg_hf_max', 'bg_hf_mean', 'bg_hf_std']
# [{'min': None, 'max': None, 'mean': None, 'std': None}]
# SIERRA NEVADA ['bg_hf_min', 'bg_hf_max', 'bg_hf_mean', 'bg_hf_std']
# [{'min': 25.56910514831543, 'max': 546.2354125976562, 'mean': 71.53705999769014, 'std': 73.5785873989172}]
# ROCKY MOUNTAINS ['bg_hf_min', 'bg_hf_max', 'bg_hf_mean', 'bg_hf_std']
# [{'min': 4.683584690093994, 'max': 8891.2841796875, 'mean': 122.3101378377874, 'std': 407.10056920991104}]
# CASCADE RANGE ['bg_hf_min', 'bg_hf_max', 'bg_hf_mean', 'bg_hf_std']
# [{'min': 14.68442153930664, 'max': 483.9068908691406, 'mean': 98.20035677717665, 'std': 76.8799606547166}]
# MACKENZIE MTS. ['bg_hf_min', 'bg_hf_max', 'bg_hf_mean', 'bg_hf_std']
# [{'min': 44.6286506652832, 'max': 147.2287139892578, 'mean': 80.4663818099282, 'std': 14.599980974947146}]
# COAST MOUNTAINS ['bg_hf_min', 'bg_hf_max', 'bg_hf_mean', 'bg_hf_std']
# [{'min': 43.27230453491211, 'max': 214.78038024902344, 'mean': 83.51467455658023, 'std': 16.86948307753077}]
# APPALACHIAN MTS. ['bg_hf_min', 'bg_hf_max', 'bg_hf_mean', 'bg_hf_std']
# [{'min': 13.203481674194336, 'max': 750.0473022460938, 'mean': 52.598866941203816, 'std': 38.488802843460306}]
# COAST RANGES ['bg_hf_min', 'bg_hf_max', 'bg_hf_mean', 'bg_hf_std']
# [{'min': 22.338716506958008, 'max': 333.16204833984375, 'mean': 54.08095052358988, 'std': 33.639428676854834}]

# %%
dr
# Out:
#                  n_springs       area_name area_name_short  \
# Alps                   311            Alps              AL
# SIERRA NEVADA           40   Sierra Nevada              SN
# ROCKY MOUNTAINS        220       Rocky Mts              RM
# CASCADE RANGE           40        Cascades              CA
# MACKENZIE MTS.          10  Mackenzie Mts.              MK
# COAST MOUNTAINS         21    Coastal Mts.              CM
# APPALACHIAN MTS.        18    Appalachians              AP
# COAST RANGES            55  Coastal ranges              CR
#
#                                                            geometry  \
# Alps              POLYGON ((5.70251 45.47714, 5.84122 45.60113, ...
# SIERRA NEVADA     POLYGON ((-118.19841 35.11146, -118.59527 34.8...
# ROCKY MOUNTAINS   POLYGON ((-124.56524 59.71058, -123.32653 59.0...
# CASCADE RANGE     POLYGON ((-119.01110 50.86066, -119.10973 50.6...
# MACKENZIE MTS.    POLYGON ((-131.11913 65.78962, -129.73424 65.6...
# COAST MOUNTAINS   POLYGON ((-134.21074 59.93110, -134.00292 59.6...
# APPALACHIAN MTS.  POLYGON ((-64.97519 48.16923, -65.15880 48.062...
# COAST RANGES      POLYGON ((-124.31286 48.26301, -123.78905 48.1...
#
#                           area  total_heat_flow_W  spring_HF_density_mW_m-2  \
# Alps              2.023559e+11                NaN                  0.550000
# SIERRA NEVADA     7.026051e+10       1.052434e+08                  1.497902
# ROCKY MOUNTAINS   1.080046e+12       5.478040e+08                  0.507204
# CASCADE RANGE     1.428857e+11       5.388678e+07                  0.377132
# MACKENZIE MTS.    3.103657e+11       4.457039e+07                  0.143606
# COAST MOUNTAINS   2.149131e+11       2.928910e+07                  0.136283
# APPALACHIAN MTS.  8.525581e+11       3.250012e+07                  0.038121
# COAST RANGES      1.653158e+11       8.359235e+06                  0.050565
#
#                   total_discharge_m3_s  avg_background_heat_flow_mWm-2  \
# Alps                               NaN                       76.000000
# SIERRA NEVADA                 0.389213                       73.915000
# ROCKY MOUNTAINS               3.706632                      114.535455
# CASCADE RANGE                 0.296381                       54.955000
# MACKENZIE MTS.                0.243504                       77.430000
# COAST MOUNTAINS               0.156313                       63.409524
# APPALACHIAN MTS.              0.506012                       57.583333
# COAST RANGES                  0.067350                       80.318182
#
#                   percentage_of_total_heat_flow  ...  avg_rch_mean  \
# Alps                                        NaN  ...      0.506195
# SIERRA NEVADA                          2.026520  ...      0.145193
# ROCKY MOUNTAINS                        0.442836  ...      0.058075
# CASCADE RANGE                          0.686256  ...      0.390847
# MACKENZIE MTS.                         0.185466  ...      0.067756
# COAST MOUNTAINS                        0.214926  ...      0.656094
# APPALACHIAN MTS.                       0.066201  ...      0.361898
# COAST RANGES                           0.062956  ...      0.396549
#
#                   avg_rch_std  elev_min elev_max    elev_mean    elev_std  \
# Alps                 0.186473       NaN      NaN          NaN  750.000000
# SIERRA NEVADA        0.101613      50.0   4212.0  1606.575254  873.873632
# ROCKY MOUNTAINS      0.086565     258.0   4227.0  1844.225596  624.628384
# CASCADE RANGE        0.331348       0.0   4279.0  1086.987325  519.883436
# MACKENZIE MTS.       0.069006      60.0   2711.0  1132.440950  433.496132
# COAST MOUNTAINS      0.352640       0.0   3637.0  1075.431508  584.100366
# APPALACHIAN MTS.     0.150724      -9.0   1932.0   359.108211  209.363737
# COAST RANGES         0.353003      -3.0   2628.0   494.774685  431.454234
#
#                   bg_hf_min    bg_hf_max  bg_hf_mean   bg_hf_std
# Alps                    NaN          NaN   76.000000         NaN
# SIERRA NEVADA     25.569105   546.235413   71.537060   73.578587
# ROCKY MOUNTAINS    4.683585  8891.284180  122.310138  407.100569
# CASCADE RANGE     14.684422   483.906891   98.200357   76.879961
# MACKENZIE MTS.    44.628651   147.228714   80.466382   14.599981
# COAST MOUNTAINS   43.272305   214.780380   83.514675   16.869483
# APPALACHIAN MTS.  13.203482   750.047302   52.598867   38.488803
# COAST RANGES      22.338717   333.162048   54.080951   33.639429
#
# [8 rows x 26 columns]

# %% [markdown]
# ## Compare old and new HF estimates

# %%
fig, ax = pl.subplots(1, 1)

ax.scatter(dr['avg_background_heat_flow_mWm-2'], 
           dr['bg_hf_mean'])
ax.set_xlabel('mean bg hf springs Ferguson & Grasby 2011')
ax.set_ylabel('mean bg hf blackwell et al. (2004, 2011)')
# Out:
# Text(0, 0.5, 'mean bg hf blackwell et al. (2004, 2011)')

# %% [markdown]
# ## New figure heat flux orogens

# %%
ms=10
ybuffer = 0.075

yvars = ['total_discharge_mm_a-1', 'spring_HF_density_mW_m-2']
ylabels = [r'Spring discharge ($mm\;a^{-1}$)', r'Net HF springs (mW m$^{-2}$)']
ycolors = ['blue', 'orange']


ylim1 = [0, 2.0]
ylim2 = [0, 0.6]

#'spring_density',
xvars = ['elev_std',
         'avg_rch_mean',
        'bg_hf_mean']

#r'km$^2$ per spring',
xlabels = ['St.dev. elevation (m)',
           r'Groundwater recharge (m a$^{-1}$)',
          r'Background heat flow (mW m$^{-2}$)']

markers = ['*', 'o', '^', 'p', 'P', 'D', '<', 'X']

crs = ccrs.PlateCarree()

# %%
fig, axsi = pl.subplots(3, 2, figsize=(10, 8))

axsii = axsi.ravel()

axs = axsii[3:]
ax0 = axsii[2]

axrs = [ax.twinx() for ax in axs]

dr['area_name_comb'] = [a + '\n(' + b + ')' for a, b in zip(dr['area_name'].values, 
                                                           dr['area_name_short'].values)]

#ax0.scatter(dr['area_name_comb'], dr['spring_density'], marker=markers,
#            edgecolor='black', facecolor='gray')
x = np.arange(len(dr['area_name_comb'])) + 1
y = dr['spring_density'].values

for xi, yi, t, m in zip(x, y, dr['area_name_short'].values, markers):
    ax0.scatter(xi, yi, marker=m, edgecolor='black', facecolor='gray')

ax0.set_xticks(x)
ax0.set_xticklabels(dr['area_name_comb'].values, rotation=90)
#ax0.tick_params(axis='x', labelrotation=90)

ax0.set_ylabel(r'Spring density ($km^2$ spring$^{-1}$)')

ax0.set_yscale('log')

for ax, axr, xvar, xlabel in zip(axs, axrs, xvars, xlabels):
    
    #axr.scatter(dr[xvar], dr[yvar2], facecolor='none', edgecolor='blue')
    
    axis = [ax, axr]
    
    for yvar, ylabel, yc, axi in zip(yvars, ylabels, ycolors, axis):
        
        x, y = dr[xvar].values.astype(float), dr[yvar].values.astype(float)
        
        slope, intercept, r, p, se = scipy.stats.linregress(x, y)
        plotx = np.linspace(x.min(), x.max(), 101)
        ploty = intercept + slope * plotx
        print('%s, r2=%0.2f, p=%0.2f' %(xlabel, r**2, p))

        if p <= 0.05:
            axi.plot(plotx, ploty, color=yc, ls=':')

            tekst = r'r$^2$=%0.2f,p=%0.2f' % (r**2, p)
            axi.text(0.03, 0.9, tekst, color=yc, transform=axr.transAxes)

        for xi, yi, t, m in zip(x, y, dr['area_name_short'].values, markers):
            axi.scatter(xi, yi, marker=m, facecolor='none', edgecolor=yc)
            
            if axi == axis[-1]:
                axr.text(xi, yi + ybuffer, t, va='bottom', ha='center', color='black')
    
        #print(dr[xvar], dr[yvar])
    
        axi.set_ylabel(ylabel)
    
    ax.set_xlabel(xlabel)
    
#fig.legend(legs, leg_labels, loc='upper right', frameon=False)

ax0.spines['right'].set_visible(False)
ax0.spines['top'].set_visible(False)
#axrs[0].spines['right'].set_visible(False)

for i, axi in enumerate([ax0] + axs.tolist()):
    axi.spines['top'].set_visible(False)
    #axi.spines['right'].set_visible(False)
    axi.text(0.03, 1.06, string.ascii_lowercase[i + 2], 
        weight='bold', transform=axi.transAxes, ha='left', va='bottom')

for ax in axs:
    ax.yaxis.label.set_color('blue')
    ax.tick_params(axis='y', colors='blue')
    ax.set_ylim(ylim2)
    
for i, axi in enumerate(axrs):
    axi.spines['top'].set_visible(False)
    axi.yaxis.label.set_color('orange')
    axi.tick_params(axis='y', colors='orange')
    axi.set_ylim(ylim1)

for ax in axsi[0]:
    ax.set_visible(False)
    
#fig.subplots_adjust(hspace=0.45, wspace=0.45) 
fig.tight_layout()
    
fig.savefig('fig/comparison_orogens.pdf')
fig.savefig('fig/comparison_orogens.png')
# Out:
# St.dev. elevation (m), r2=0.57, p=0.03
# St.dev. elevation (m), r2=0.70, p=0.01
# Groundwater recharge (m a$^{-1}$), r2=0.00, p=0.97
# Groundwater recharge (m a$^{-1}$), r2=0.13, p=0.38
# Background heat flow (mW m$^{-2}$), r2=0.02, p=0.72
# Background heat flow (mW m$^{-2}$), r2=0.02, p=0.71

# %%
axs
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe1b56cea58>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fe1b56bfb38>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fe1b56d7c88>],
#       dtype=object)

# %%
help(ax0.set_xticks)
# Out:
# Help on method set_xticks in module matplotlib.axes._base:
#
# set_xticks(ticks, minor=False) method of matplotlib.axes._subplots.AxesSubplot instance
#     Set the x ticks with list of *ticks*
#
#     Parameters
#     ----------
#     ticks : list
#         List of x-axis tick locations.
#
#     minor : bool, optional
#         If ``False`` sets major ticks, if ``True`` sets minor ticks.
#         Default is ``False``.

# %%
fig = pl.figure(figsize=(6, 6))

axs = [fig.add_subplot(2, 1, 1, projection=crs)]

axs += [fig.add_subplot(2, 1, 2)]

####### map thermal springs USA

axs[0].stock_img()

# show areas
for area_i, area, short_label in zip(itertools.count(), areas, area_labels_short):
    
    print(area, short_label)
    
    ind = da['name'] == area
    #print(da.loc[ind])
    dai = da.loc[ind]
    
    if area in da['name'].values:
        
        #dai.plot(ax=ax, color='gray')
        axs[0].add_geometries(dai['geometry'], facecolor='none', edgecolor='blue', crs=crs, zorder=100)
        
        d = dai['geometry'].centroid.values[0]
        c = d.coords[:][0]
        axs[0].text(c[0], c[1], short_label, fontsize='large',
                    va='center', ha='center', transform=crs, weight='bold', zorder=102)

        #dsi.plot(ax=ax, edgecolor='black', facecolor='None')

# show springs
axs[0].scatter(ds['Longitude'], ds['Latitude'], edgecolor='red', facecolor='none', 
               s=3, alpha=0.5,
               transform=crs, zorder=99)

axs[0].set_xlim(-140, -60)
axs[0].set_ylim(30, 70)

axs[0].coastlines()
        
gl = axs[0].gridlines(xlocs=[-140, -120, -100, -80, -60], ylocs=[20, 40, 60, 80], 
                      crs=crs, zorder=2001, linestyle=':', 
                      draw_labels=True)

gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabels_top = False
gl.ylabels_right = False

ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
##############

axl = axs[-1]
axr = axs[-1].twinx()

axl.scatter(dr['area_name_short'], dr[yvar2], facecolor='none', edgecolor='blue', s=s)

#ax.set_xlabel()
axl.set_ylabel(ylabel2)

axr.scatter(dr['area_name_short'], dr[yvar], facecolor='none', marker='^', edgecolor='orange', s=s)
    
axr.set_ylabel(ylabel)

xt = axl.get_xticks()

n = dr['area_name']
ns = dr['area_name_short']

new_labels = [ni + ' (%s)' % nsi for ni, nsi in zip(n, ns)]
xt[:] = new_labels[:]
axl.set_xticklabels(xt, rotation=90)

for i, axi in enumerate(axs):
    axi.spines['top'].set_visible(False)
    #axi.spines['right'].set_visible(False)
    axi.text(0.03, 1.06, string.ascii_lowercase[i], 
        weight='bold', transform=axi.transAxes, ha='left', va='bottom')

axl.yaxis.label.set_color('blue')
axl.tick_params(axis='y', colors='blue')
axl.set_ylim(ylim2)
    
axr.spines['top'].set_visible(False)
axr.yaxis.label.set_color('orange')
axr.tick_params(axis='y', colors='orange')
axr.set_ylim(ylim1)

fig.subplots_adjust(hspace=0.45, wspace=0.45) 
fig.tight_layout()
    
fig.savefig('fig/comparison_orogens_simple.pdf')
fig.savefig('fig/comparison_orogens_simple.png')
# Out:
# Alps AL
# APPALACHIAN MTS. AP
# CASCADE RANGE CA
# COAST MOUNTAINS CM
# COAST RANGES CR
# MACKENZIE MTS. MK
# ROCKY MOUNTAINS RM
# SIERRA NEVADA SN
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:92: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.

# %% [markdown]
# ## Save data:

# %%
fno = 'data/comparison_heat_flux_orogens.csv'
dr.to_csv(fno, index_label='area')
